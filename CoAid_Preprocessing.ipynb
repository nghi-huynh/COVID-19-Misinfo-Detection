# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Importing CoAID

# %%
# Read dataset 05-01-2020
claim_fake_path   = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/05-01-2020/ClaimFakeCOVID-19.csv"
claim_real_path   = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/05-01-2020/ClaimRealCOVID-19.csv"
claim_fake_t_path = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/05-01-2020/ClaimFakeCOVID-19_tweets.csv"
claim_real_t_path = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/05-01-2020/ClaimRealCOVID-19_tweets.csv"
news_fake_path    = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/05-01-2020/NewsFakeCOVID-19.csv"
news_real_path    = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/05-01-2020/NewsRealCOVID-19.csv"
news_fake_t_path  = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/05-01-2020/NewsFakeCOVID-19_tweets.csv"
news_real_t_path  = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/05-01-2020/NewsRealCOVID-19_tweets.csv"

claim_fake_dat    = pd.read_csv(claim_fake_path)
claim_real_dat    = pd.read_csv(claim_real_path)
claim_fake_t_dat  = pd.read_csv(claim_fake_t_path)
claim_real_t_dat  = pd.read_csv(claim_real_t_path)
news_fake_dat     = pd.read_csv(news_fake_path)
news_real_dat     = pd.read_csv(news_real_path)
news_fake_t_dat   = pd.read_csv(news_fake_t_path)
news_real_t_dat   = pd.read_csv(news_real_t_path)

# %%
claim_0 = claim_fake_t_dat.drop(labels="index",axis=1)
claim_0.to_csv('claim_0.csv',header=False,index=False)
claim_1 = claim_real_t_dat.drop(labels="index",axis=1)
claim_1.to_csv('claim_1.csv',header=False,index=False)
news_0  = news_fake_t_dat.drop(labels="index",axis=1)
news_0.to_csv('news_0.csv',header=False,index=False)
news_1  = news_real_t_dat.drop(labels="index",axis=1)
news_1.to_csv('news_1.csv',header=False,index=False)

# %%
# Read dataset 07-01-2020
claim_fake_07_path   = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/07-01-2020/ClaimFakeCOVID-19.csv"
claim_real_07_path   = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/07-01-2020/ClaimRealCOVID-19.csv"
claim_fake_07_t_path = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/07-01-2020/ClaimFakeCOVID-19_tweets.csv"
claim_real_07_t_path = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/07-01-2020/ClaimRealCOVID-19_tweets.csv"
news_fake_07_path    = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/07-01-2020/NewsFakeCOVID-19.csv"
news_real_07_path    = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/07-01-2020/NewsRealCOVID-19.csv"
news_fake_07_t_path  = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/07-01-2020/NewsFakeCOVID-19_tweets.csv"
news_real_07_t_path  = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/07-01-2020/NewsRealCOVID-19_tweets.csv"

claim_fake_07_dat    = pd.read_csv(claim_fake_07_path)
claim_real_07_dat    = pd.read_csv(claim_real_07_path)
claim_fake_07_t_dat  = pd.read_csv(claim_fake_07_t_path)
claim_real_07_t_dat  = pd.read_csv(claim_real_07_t_path)
news_fake_07_dat     = pd.read_csv(news_fake_07_path)
news_real_07_dat     = pd.read_csv(news_real_07_path)
news_fake_07_t_dat   = pd.read_csv(news_fake_07_t_path)
news_real_07_t_dat   = pd.read_csv(news_real_07_t_path)

# %%
claim_0 = claim_fake_07_t_dat.drop(labels="index",axis=1)
claim_0.to_csv('claim_07_0.csv',header=False,index=False)
claim_1 = claim_real_07_t_dat.drop(labels="index",axis=1)
claim_1.to_csv('claim_07_1.csv',header=False,index=False)
news_0  = news_fake_07_t_dat.drop(labels="index",axis=1)
news_0.to_csv('news_07_0.csv',header=False,index=False)
news_1  = news_real_07_t_dat.drop(labels="index",axis=1)
news_1.to_csv('news_07_1.csv',header=False,index=False)

# %%
# Read dataset 09-01-2020
#claim_fake_09_path   = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/09-01-2020/ClaimFakeCOVID-19.csv"
claim_real_09_path   = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/09-01-2020/ClaimRealCOVID-19.csv"
#claim_fake_09_t_path = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/09-01-2020/ClaimFakeCOVID-19_tweets.csv"
claim_real_09_t_path = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/09-01-2020/ClaimRealCOVID-19_tweets.csv"
news_fake_09_path    = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/09-01-2020/NewsFakeCOVID-19.csv"
news_real_09_path    = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/09-01-2020/NewsRealCOVID-19.csv"
news_fake_09_t_path  = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/09-01-2020/NewsFakeCOVID-19_tweets.csv"
news_real_09_t_path  = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/09-01-2020/NewsRealCOVID-19_tweets.csv"

#claim_fake_09_dat    = pd.read_csv(claim_fake_09_path)
claim_real_09_dat    = pd.read_csv(claim_real_09_path)
#claim_fake_09_t_dat  = pd.read_csv(claim_fake_09_t_path)
claim_real_09_t_dat  = pd.read_csv(claim_real_09_t_path)
news_fake_09_dat     = pd.read_csv(news_fake_09_path)
news_real_09_dat     = pd.read_csv(news_real_09_path)
news_fake_09_t_dat   = pd.read_csv(news_fake_09_t_path)
news_real_09_t_dat   = pd.read_csv(news_real_09_t_path)

# %%
#claim_0 = claim_fake_09_t_dat.drop(labels="index",axis=1)
#claim_0.to_csv('claim_09_0.csv',header=False,index=False)
claim_1 = claim_real_09_t_dat.drop(labels="index",axis=1)
claim_1.to_csv('claim_09_1.csv',header=False,index=False)
news_0  = news_fake_09_t_dat.drop(labels="index",axis=1)
news_0.to_csv('news_09_0.csv',header=False,index=False)
news_1  = news_real_09_t_dat.drop(labels="index",axis=1)
news_1.to_csv('news_09_1.csv',header=False,index=False)

# %%
# Read dataset 11-01-2020
claim_real_11_path   = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/11-01-2020/ClaimRealCOVID-19.csv"
claim_real_11_t_path = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/11-01-2020/ClaimRealCOVID-19_tweets.csv"
news_fake_11_path    = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/11-01-2020/NewsFakeCOVID-19.csv"
news_real_11_path    = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/11-01-2020/NewsRealCOVID-19.csv"
news_fake_11_t_path  = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/11-01-2020/NewsFakeCOVID-19_tweets.csv"
news_real_11_t_path  = "/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_dataset/11-01-2020/NewsRealCOVID-19_tweets.csv"

claim_real_11_dat    = pd.read_csv(claim_real_11_path)
claim_real_11_t_dat  = pd.read_csv(claim_real_11_t_path)
news_fake_11_dat     = pd.read_csv(news_fake_11_path)
news_real_11_dat     = pd.read_csv(news_real_11_path)
news_fake_11_t_dat   = pd.read_csv(news_fake_11_t_path)
news_real_11_t_dat   = pd.read_csv(news_real_11_t_path)

# %%
claim_1 = claim_real_11_t_dat.drop(labels="index",axis=1)
claim_1.to_csv('claim_11_1.csv',header=False,index=False)
news_0  = news_fake_11_t_dat.drop(labels="index",axis=1)
news_0.to_csv('news_11_0.csv',header=False,index=False)
news_1  = news_real_11_t_dat.drop(labels="index",axis=1)
news_1.to_csv('news_11_1.csv',header=False,index=False)

# %% [markdown]
# # Cleaning CoAID

# %% [markdown]
# ## Clean website dataset

# %%
def clean_news(news_dat,label):
  if label == 0: # fake news
    clean_dat = news_dat.drop(['Unnamed: 0','archive','news_url2','news_url3','news_url4','news_url5','publish_date'],axis=1)
  elif label == 1: # real news
    clean_dat = news_dat.drop(['Unnamed: 0','publish_date'],axis=1)
  return clean_dat

# %%
# Dataset 05-01-2020
claim_fake_dat.shape
# Out:
# (27, 4)

# %%
claim_real_dat.shape
# Out:
# (166, 4)

# %%
news_05_web_0 = clean_news(news_fake_dat,0)
news_05_web_0.to_csv('news_05_web_0.csv')
news_05_web_0.shape
# Out:
# (572, 8)

# %%
news_05_web_1 = clean_news(news_real_dat,1)
news_05_web_1.to_csv('news_05_web_1.csv')
news_05_web_1.shape
# Out:
# (1590, 8)

# %%
# Dataset 07-01-2020
news_07_web_0 = clean_news(news_fake_07_dat,0) #news on different platforms
news_07_web_1 = clean_news(news_real_07_dat,1)
news_07_web_0.to_csv('news_07_web_0.csv')
news_07_web_1.to_csv('news_07_web_1.csv')

# %%
# Dataset 09-01-2020
news_09_web_0 = clean_news(news_fake_09_dat,0)
news_09_web_1 = clean_news(news_real_09_dat,1)
news_09_web_0.to_csv('news_09_web_0.csv')
news_09_web_1.to_csv('news_09_web_1.csv')

# %%
# Dataset 11-01-2020
news_11_web_0 = clean_news(news_fake_11_dat,0)
news_11_web_1 = clean_news(news_real_11_dat,1)
news_11_web_0.to_csv('news_11_web_0.csv')
news_11_web_1.to_csv('news_11_web_1.csv')

# %% [markdown]
# ## Clean Tweets dataset

# %%
def clean_tweets(tweets_dat):
  #if label == 0:
  clean_tweets = tweets_dat.drop(['coordinates','urls','id','in_reply_to_screen_name','in_reply_to_status_id','in_reply_to_user_id','lang','place','retweet_id','retweet_screen_name','tweet_url','user_screen_name','user_default_profile_image','user_name','user_screen_name.1','user_time_zone','user_urls'],axis=1)
  return clean_tweets

# %% [markdown]
# **Load the hydrated datasest**

# %%
# 05-01-2020
claim_05_t_0 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/05-01-2020/05_claim_0.csv")
claim_05_t_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/05-01-2020/05_claim_1.csv")
news_05_t_0  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/05-01-2020/05_news_0.csv")
news_05_t_1  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/05-01-2020/05_news_1.csv")

# 07-01-2020
claim_07_t_0 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/07-01-2020/07_claim_0.csv")
claim_07_t_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/07-01-2020/07_claim_1.csv")
news_07_t_0  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/07-01-2020/07_news_0.csv")
news_07_t_1  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/07-01-2020/07_news_1.csv")

# 09-01-2020
claim_09_t_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/09-01-2020/09_claim_1.csv")
news_09_t_0  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/09-01-2020/09_news_0.csv")
news_09_t_1  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/09-01-2020/09_news_1.csv")

# 11-01-2020
claim_11_t_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/11-01-2020/11_claim_1.csv")
news_11_t_0  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/11-01-2020/11_news_0.csv")
news_11_t_1  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Data_Challenge_2021/CoAID_Preprocessed/11-01-2020/11_news_1.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
claim_05_t_1.head()

# %% [markdown]
# **Clean tweets**

# %%
# 05-01-2020
clean_claim_05_t_0 = clean_tweets(claim_05_t_0)
clean_claim_05_t_1 = clean_tweets(claim_05_t_1)
clean_news_05_t_0  = clean_tweets(news_05_t_0)
clean_news_05_t_1  = clean_tweets(news_05_t_1)
print(clean_claim_05_t_0.shape)

# 07-01-2020
clean_claim_07_t_0 = clean_tweets(claim_07_t_0)
clean_claim_07_t_1 = clean_tweets(claim_07_t_1)
clean_news_07_t_0  = clean_tweets(news_07_t_0)
clean_news_07_t_1  = clean_tweets(news_07_t_1)

# 09-01-2020
clean_claim_09_t_1 = clean_tweets(claim_09_t_1)
clean_news_09_t_0  = clean_tweets(news_09_t_0)
clean_news_09_t_1  = clean_tweets(news_09_t_1)

# 11-01-2020
clean_claim_11_t_1 = clean_tweets(claim_11_t_1)
clean_news_11_t_0  = clean_tweets(news_11_t_0)
clean_news_11_t_1  = clean_tweets(news_11_t_1)
# Out:
# (370, 17)

# %% [markdown]
# **Save clean tweets**

# %%
# 05-01-2020
clean_claim_05_t_0.to_csv('clean_claim_05_t_0.csv')
clean_claim_05_t_1.to_csv('clean_claim_05_t_1.csv')
clean_news_05_t_0.to_csv('clean_news_05_t_0.csv')
clean_news_05_t_1.to_csv('clean_news_05_t_1.csv')

# %%
# 07-01-2020
clean_claim_07_t_0.to_csv('clean_claim_07_t_0.csv')
clean_claim_07_t_1.to_csv('clean_claim_07_t_1.csv')
clean_news_07_t_0.to_csv('clean_news_07_t_0.csv')
clean_news_07_t_1.to_csv('clean_news_07_t_1.csv')

# %%
# 09-01-2020
clean_claim_09_t_1.to_csv('clean_claim_09_t_1.csv')
clean_news_09_t_0.to_csv('clean_news_09_t_0.csv')
clean_news_09_t_1.to_csv('clean_news_09_t_1.csv')

# %%
# 11-01-2020
clean_claim_11_t_1.to_csv('clean_claim_11_t_1.csv')
clean_news_11_t_0.to_csv('clean_news_11_t_0.csv')
clean_news_11_t_1.to_csv('clean_news_11_t_1.csv')

# %%
clean_claim_11_t_1.head()
